# %%
import mido
msg = mido.Message('note_on', note=60)
msg.type
msg.note
msg.bytes()
msg.copy(channel=2)
# Out:
# <message note_on channel=2 note=60 velocity=64 time=0>

# %%
mid = mido.MidiFile('ExtraitsMidi/une-souris-verte.mid')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-66785a43e6d6> in <module>()
# ----> 1 mid = mido.MidiFile('ExtraitsMidi/une-souris-verte.mid')
#
# ~\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in __init__(self, filename, file, type, ticks_per_beat, charset, debug, clip)
#     314         elif self.filename is not None:
#     315             with io.open(filename, 'rb') as file:
# --> 316                 self._load(file)
#     317
#     318     def add_track(self, name=None):
#
# ~\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in _load(self, infile)
#     338             (self.type,
#     339              num_tracks,
# --> 340              self.ticks_per_beat) = read_file_header(infile)
#     341
#     342             if self.debug:
#
# ~\Anaconda3\lib\site-packages\mido\midifiles\midifiles.py in read_file_header(infile)
#     109
# ...

# %%
for msg in mid :
    print(msg)
# Out:
# <meta message time_signature numerator=4 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>
# <meta message key_signature key='C' time=0>
# <meta message set_tempo tempo=500000 time=0>
# program_change channel=1 program=73 time=0
# control_change channel=1 control=121 value=0 time=0
# control_change channel=1 control=64 value=0 time=0
# control_change channel=1 control=91 value=52 time=0
# control_change channel=1 control=10 value=70 time=0
# control_change channel=1 control=7 value=121 time=0
# <meta message track_name name='Flute' time=0>
# note_on channel=1 note=72 velocity=89 time=0
# program_change channel=0 program=0 time=0
# control_change channel=0 control=121 value=0 time=0
# control_change channel=0 control=64 value=0 time=0
# control_change channel=0 control=91 value=48 time=0
# control_change channel=0 control=10 value=51 time=0
# control_change channel=0 control=7 value=80 time=0
# control_change channel=0 control=121 value=0 time=0
# ...
